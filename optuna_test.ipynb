# %%
import optuna

# %%
def objective(trial):
    x = trial.suggest_float('x', -10, 10)
    return (x - 2) ** 2

study = optuna.create_study()
study.optimize(objective, n_trials=100)
# Out:
# [I 2022-05-12 23:38:55,566] A new study created in memory with name: no-name-080a7659-9b00-4ce7-9356-1fd6766a78d1
# [I 2022-05-12 23:38:55,569] Trial 0 finished with value: 0.7564184991379542 and parameters: {'x': 2.8697232313431407}. Best is trial 0 with value: 0.7564184991379542.
# [I 2022-05-12 23:38:55,569] Trial 1 finished with value: 2.744066791780442 and parameters: {'x': 3.6565224996300056}. Best is trial 0 with value: 0.7564184991379542.
# [I 2022-05-12 23:38:55,571] Trial 2 finished with value: 133.68151884779323 and parameters: {'x': -9.562072428755721}. Best is trial 0 with value: 0.7564184991379542.
# [I 2022-05-12 23:38:55,572] Trial 3 finished with value: 8.728147222099235 and parameters: {'x': -0.9543437887455202}. Best is trial 0 with value: 0.7564184991379542.
# [I 2022-05-12 23:38:55,573] Trial 4 finished with value: 0.03056798780148062 and parameters: {'x': 1.8251629678772812}. Best is trial 4 with value: 0.03056798780148062.
# ...

# %%
study.best_params
# Out:
# {'x': 1.9983191226815777}
