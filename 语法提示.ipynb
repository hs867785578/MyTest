# %%
import numpy as np

# %%
def test(s):
    return s.split(',')#split无提示

# %%
def test_2(s:str):
    return s.split(',')#split有提示

# %%
from typing import NewType
UserId = NewType('UserId', int)
def name_by_id(user_id: UserId) -> str:
    print(user_id)

name_by_id(UserId(5))
name_by_id(5)
# Out:
# 5
# 5
